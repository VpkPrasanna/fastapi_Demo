# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
import pickle

# %%
dataset = pd.read_csv('Dataset/Boston.csv')
dataset.head()
# Out:
#    1     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0  2  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1  3  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2  4  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3  5  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4  6  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
dataset.isnull().sum()
# Out:
# 1          0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ### There is no null or nan values in the dataset

# %%
y = dataset['medv']
x = dataset.drop(['medv','1'],axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.33, random_state=42)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X_test)

# %%
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)

# %%
print(mae)
print(mse)
# Out:
# 3.1482557548168266
# 20.724023437339728

# %%
filename = 'linear-house-price.pkl'
pickle.dump(lr, open(filename, 'wb'))

# %%
X_train
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 478  10.23300   0.0  18.10     0  0.614  6.185  96.7  2.1705   24  666
# 26    0.67191   0.0   8.14     0  0.538  5.813  90.3  4.6820    4  307
# 7     0.14455  12.5   7.87     0  0.524  6.172  96.1  5.9505    5  311
# 492   0.11132   0.0  27.74     0  0.609  5.983  83.5  2.1099    4  711
# 108   0.12802   0.0   8.56     0  0.520  6.474  97.1  2.4329    5  384
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384
#
#      ptratio   black  lstat
# 478     20.2  379.70  18.03
# 26      21.0  376.88  14.81
# 7       15.2  396.90  19.15
# 492     20.1  396.90  13.35
# 108     20.9  395.24  12.27
# ..       ...     ...    ...
# 106     20.9  395.67  18.66
# 270     18.6  388.65  13.00
# 348     17.0  390.94   5.99
# 435     20.2  109.85  23.27
# 102     20.9   70.80  10.63
#
# [339 rows x 13 columns]
